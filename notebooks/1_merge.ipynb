# %%
import pandas as pd
import glob
from os import listdir

# %%
datasets_loc = glob.glob( '../datasets/*/**.csv' )

# %%
datasets_loc
# Out:
# ['../datasets/👌/tweets.csv',
#  '../datasets/👍/tweets.csv',
#  '../datasets/💞/tweets.csv',
#  '../datasets/😂/tweets.csv',
#  '../datasets/😋/tweets.csv',
#  '../datasets/😌/tweets.csv',
#  '../datasets/😩/tweets.csv',
#  '../datasets/😴/tweets.csv',
#  '../datasets/😍/tweets.csv',
#  '../datasets/😳/tweets.csv',
#  '../datasets/😊/tweets.csv',
#  '../datasets/🙏/tweets.csv',
#  '../datasets/🙈/tweets.csv',
#  '../datasets/😄/tweets.csv',
#  '../datasets/😑/tweets.csv',
#  '../datasets/😘/tweets.csv',
#  '../datasets/✌️/tweets.csv',
#  '../datasets/🌞/tweets.csv',
#  '../datasets/☺️/tweets.csv',
#  '../datasets/👶/tweets.csv',
#  '../datasets/💕/tweets.csv',
#  '../datasets/🇳🇵/tweets.csv',
#  '../datasets/😔/tweets.csv',
#  '../datasets/😭/tweets.csv',
#  '../datasets/😁/tweets.csv',
#  '../datasets/😏/tweets.csv',
#  '../datasets/😱/tweets.csv',
#  '../datasets/😈/tweets.csv',
#  '../datasets/😒/tweets.csv',
#  '../datasets/😜/tweets.csv',
#  '../datasets/😉/tweets.csv',
#  '../datasets/☕/tweets.csv',
# ...

# %%
df = None
for loc in datasets_loc:
    if df is None:
        df = pd.read_csv(loc)
        df['emoji'] = loc.split("/")[2]
    else:
        df_temp = pd.read_csv(loc)
        df_temp['emoji'] = loc.split("/")[2]
        df = df.append(df_temp)

# %%
df
# Out:
#                        id      conversation_id                 created_at  \
# 0     1398437418768818176  1398437418768818176  2021-05-29 06:18:57 +0545
# 1     1397792077149216769  1397791412687495168  2021-05-27 11:34:35 +0545
# 2     1397341721566990336  1383799053113171968  2021-05-26 05:45:02 +0545
# 3     1394863068035813379  1394863068035813379  2021-05-19 09:35:45 +0545
# 4     1393821979032133635  1393821979032133635  2021-05-16 12:38:50 +0545
# ...                   ...                  ...                        ...
# 2228   389751359874289664   389751359874289664  2013-10-14 19:40:40 +0545
# 2229   389704517815902208   389704517815902208  2013-10-14 16:34:32 +0545
# 2230   387917234490048512   387917234490048512  2013-10-09 18:12:30 +0545
# 2231   387542385145954304   387542385145954304  2013-10-08 17:22:59 +0545
# 2232   386357639460179968   386357639460179968  2013-10-05 10:55:14 +0545
#
#             date      time  timezone              user_id      username  \
# ...

# %%
df.emoji.value_counts()
# Out:
# 😂     7576
# 😊     4016
# 😍     3781
# 😁     3482
# 🇳🇵    2785
# 😎     2270
# ❤️    2233
# 🙏     2122
# 😉     2000
# 😜     1463
# 😘     1432
# 😋     1241
# 💕     1173
# 😄     1095
# 👍     1001
# 👌      730
# 😭      637
# 😏      554
# ✌️     505
# 😒      483
# 💞      461
# 😇      432
# 🙌      423
# ☺️     375
# 😔      373
# 😌      332
# 😱      314
# 😑      296
# 😈      292
# 🙈      291
# ☕      277
# 🌞      213
# 😳      185
# 😩      181
# 😴      163
# 😷      135
# 👶       45
# Name: emoji, dtype: int64

# %%
list(df)
# Out:
# ['id',
#  'conversation_id',
#  'created_at',
#  'date',
#  'time',
#  'timezone',
#  'user_id',
#  'username',
#  'name',
#  'place',
#  'tweet',
#  'language',
#  'mentions',
#  'urls',
#  'photos',
#  'replies_count',
#  'retweets_count',
#  'likes_count',
#  'hashtags',
#  'cashtags',
#  'link',
#  'retweet',
#  'quote_url',
#  'video',
#  'thumbnail',
#  'near',
#  'geo',
#  'source',
#  'user_rt_id',
#  'user_rt',
#  'retweet_id',
#  'reply_to',
#  'retweet_date',
#  'translate',
#  'trans_src',
#  'trans_dest',
#  'emoji']

# %%
df[['id', 'emoji', 'date', 'username', 'tweet', 'likes_count', 'place']].to_csv('../datasets/merged.csv', index=False)
